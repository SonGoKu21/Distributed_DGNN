# %%
import dill
from collections import defaultdict
from datetime import datetime, timedelta

links = []
ts = []
ctr = 0
node_cnt = 0
node_idx = {}
idx_node = []

with open('soc-epinions-trust-dir/soc-epinions-trust-dir.edges') as f:
    lines = f.read().splitlines()
    for l in lines:
        if l[0] == '%':
            continue
            
        x, y, e, t = map(int, l.split(' '))
        # print (x,y,e,t)
        timestamp = datetime.fromtimestamp(t)
        ts.append(timestamp)
        
        ctr += 1
        if ctr % 100000 == 0:
            print (ctr)
            
        if x not in node_idx:
            node_idx[x] = node_cnt 
            node_cnt += 1
            
        if y not in node_idx:
            node_idx[y] = node_cnt 
            node_cnt += 1
    
        links.append((node_idx[x],node_idx[y], timestamp))

print ("Min ts", min(ts), "max ts", max(ts))    
print ("Total time span: {} days".format((max(ts) - min(ts)).days))
# sort links by the timestamp
links.sort(key =lambda x: x[2])
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# ('Min ts', datetime.datetime(2001, 1, 10, 8, 0), 'max ts', datetime.datetime(2003, 8, 12, 7, 0))
# Total time span: 943 days

# %%
import networkx as nx
import numpy as np
from datetime import datetime, timedelta
SLICE_DAYS = 10
START_DATE = min(ts) + timedelta(5)
END_DATE = max(ts) - timedelta(60)

slices_links = defaultdict(lambda : nx.MultiGraph())  # multiGraph 为多重边图
slices_features = defaultdict(lambda : {})

print ("Start date", START_DATE)

slice_id = 0
# Split the set of links in order by slices to create the graphs.
for (a, b, time) in links:
    prev_slice_id = slice_id
    
    datetime_object = time
    if datetime_object < START_DATE:
        continue
    if datetime_object > END_DATE:
        break
        days_diff = (END_DATE - START_DATE).days
    else:
        days_diff = (datetime_object - START_DATE).days
        
    
    slice_id = days_diff // SLICE_DAYS
    
    if slice_id == 1+prev_slice_id and slice_id > 0:
        slices_links[slice_id] = nx.MultiGraph()
        slices_links[slice_id].add_nodes_from(slices_links[slice_id-1].nodes(data=True))
        assert (len(slices_links[slice_id].edges()) ==0)
        #assert len(slices_links[slice_id].nodes()) >0

    if slice_id == 1+prev_slice_id and slice_id ==0:
        slices_links[slice_id] = nx.MultiGraph()

    if a not in slices_links[slice_id]:
        slices_links[slice_id].add_node(a)
    if b not in slices_links[slice_id]:
        slices_links[slice_id].add_node(b)
    slices_links[slice_id].add_edge(a,b, date=datetime_object)


for slice_id in slices_links:
    print ("# nodes in slice", slice_id, len(slices_links[slice_id].nodes()))
    print ("# edges in slice", slice_id, len(slices_links[slice_id].edges()))
    
    temp = np.identity(len(slices_links[max(slices_links.keys())].nodes()))
    print ("Shape of temp matrix", temp.shape)
    slices_features[slice_id] = {}
    for idx, node in enumerate(slices_links[slice_id].nodes()):
        slices_features[slice_id][node] = temp[idx]

# TODO : remap and output.
# Out:
# ('Start date', datetime.datetime(2001, 1, 15, 8, 0))
# ('# nodes in slice', 0, 2363)
# ('# edges in slice', 0, 2545)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 1, 4320)
# ('# edges in slice', 1, 3655)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 2, 5865)
# ('# edges in slice', 2, 3886)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 3, 7298)
# ('# edges in slice', 3, 5026)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 4, 8690)
# ('# edges in slice', 4, 5055)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 5, 10581)
# ('# edges in slice', 5, 6108)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 6, 12354)
# ('# edges in slice', 6, 7698)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 7, 13616)
# ('# edges in slice', 7, 5943)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice',

# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 69, 49490)
# ('# edges in slice', 69, 2228)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 70, 49781)
# ('# edges in slice', 70, 1420)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 71, 50241)
# ('# edges in slice', 71, 2193)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 72, 50626)
# ('# edges in slice', 72, 1907)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 73, 51002)
# ('# edges in slice', 73, 2109)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 74, 51300)
# ('# edges in slice', 74, 1882)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 75, 51695)
# ('# edges in slice', 75, 2214)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 76, 51963)
# ('# edges in slice', 76, 1707)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 77, 52306)
# ('# edges in slice', 77, 1748)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 78, 52511)
# ('# edges in slice', 78, 1157)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 79, 52729)
# ('# edges in slice', 79, 1376)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 80, 53031)
# ('# edges in slice', 80, 1712)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 81, 53292)
# ('# edges in slice', 81, 1858)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 82, 53544)
# ('# edges in slice', 82, 1472)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 83, 53825)
# ('# edges in slice', 83, 1398)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 84, 54087)
# ('# edges in slice', 84, 1405)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 85, 54446)
# ('# edges in slice', 85, 1572)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 86, 54775)
# ('# edges in slice', 86, 1768)
# ('Shape of temp matrix', (55024, 55024))
# ('# nodes in slice', 87, 55024)
# ('# edges in slice', 87, 1835)
# ('Shape of temp matrix', (55024, 55024))

# %%
from scipy.sparse import csr_matrix

def remap(slices_graph, slices_features):
    all_nodes = []
    for slice_id in slices_graph:
        assert len(slices_graph[slice_id].nodes()) == len(slices_features[slice_id])
        all_nodes.extend(slices_graph[slice_id].nodes())
    all_nodes = list(set(all_nodes))
    print ("Total # nodes", len(all_nodes), "max idx", max(all_nodes))
    ctr = 0

    node_idx = {}
    idx_node = []
    for slice_id in slices_graph:
        for node in slices_graph[slice_id].nodes():
            if node not in node_idx:
                node_idx[node] = ctr
                idx_node.append(node)
                ctr += 1
    slices_graph_remap = []
    slices_features_remap = []
    for slice_id in slices_graph:
        G = nx.MultiGraph()
        for x in slices_graph[slice_id].nodes():
            G.add_node(node_idx[x])
        for x in slices_graph[slice_id].edges(data=True):
            G.add_edge(node_idx[x[0]], node_idx[x[1]], date=x[2]['date'])
        assert (len(G.nodes()) == len(slices_graph[slice_id].nodes()))
        assert (len(G.edges()) == len(slices_graph[slice_id].edges()))
        slices_graph_remap.append(G)

    for slice_id in slices_features:
        features_remap = []
        for x in slices_graph_remap[slice_id].nodes():
            features_remap.append(slices_features[slice_id][idx_node[x]])
            #features_remap.append(np.array(slices_features[slice_id][idx_node[x]]).flatten())
        features_remap = csr_matrix(np.squeeze(np.array(features_remap)))
        slices_features_remap.append(features_remap)
    return (slices_graph_remap, slices_features_remap)

slices_links_remap, slices_features_remap = remap(slices_links, slices_features)
np.savez('/home/plab-pc2/DySAT/DySAT-master/raw_data/epinion/epinion_new/graphs.npz', graph=slices_links_remap)
np.savez('/home/plab-pc2/DySAT/DySAT-master/raw_data/epinion/epinion_new/features.npz', feats=slices_features_remap)

# %%
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-c5b9e386fd3d> in <module>()
# ----> 1 slices_links_remap, slices_features_remap = remap(slices_links, slices_features)
#       2 np.savez('/home/plab-pc2/DySAT/DySAT-master/raw_data/epinion/epinion_new/graphs.npz', graph=slices_links_remap)
#       3 np.savez('/home/plab-pc2/DySAT/DySAT-master/raw_data/epinion/epinion_new/features.npz', feats=slices_features_remap)
#
# NameError: name 'remap' is not defined
